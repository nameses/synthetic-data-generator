# %% [markdown]
# ```markdown
# # Проєкт: Генерація синтетичних даних з використанням нейронних мереж GAN та VAE
# ## Мета
# Мета проєкту - генерація високоякісних синтетичних табличних даних на основі датасету. При чому, кінцевий користувач проєкту може контролювати процес тренування та генерації даних за допомогою налаштувань нейронної мережі та переданих метаданих
# ## Архітектура
# Основу проєкту складає **GAN-мережа**, доповнена наступними механізмами:
# - **Кореляційна регуляризація** — збереження внутрішніх залежностей між числовими полями
# - **Gumbel-Softmax** — обробка категоріальних даних із градієнтами
# //todo
#
# ## Метадані
# Всі колонки датасету описуються через метадані (тип даних, трансформація, налаштування):
# - `Можливі типи даних` - цілі числа, числа з плаваючою комою, категоріальні, булеві змінні, дата/час, строка
# - //todo опис налаштувань відповідно до типів даних
# - //todo опис налаштувань метаданих
#
# ## Компоненти
# - модуль GAN
# - модуль VAE
# - //todo модуль генерації графіків та статистики (можливо перенесений в юпітер)
# - //todo модуль з моделями даних field_metadata та enum
#
# ## Аналіз тренування
# //todo опис графіків з результатами тренування
#
# ## Приклади застосування
# //todo коли буде визначений список прикладів
# 1. **Доповнення датасету** для покращення класифікації задоволеності клієнтів авіакомпанії
# 2. **Побудова time-series сценаріїв** на основі штучно згенерованої історії ARIMA
# 3. **Класифікація sliding window** або аномалій на основі збагачених даних
# ```
